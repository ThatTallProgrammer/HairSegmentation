# %%
import os

import tensorflow as tf
import keras 

import numpy as np

from PIL import Image

import winsound

from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import concatenate

from tensorflow.keras import Model

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow.keras.backend as K

from tensorflow.keras.backend import set_session, clear_session, get_session
# Out:
# Using TensorFlow backend.

# %%
# global variables

standard_epochs = 100  # epochs for unaugmented data
augmented_epochs = 100 # epochs for augmented data
resize_shape=(256, 256)
batch_size = 10
steps_per_epoch = int(1500 / batch_size) + 1 

weights_file = "highest.hdf5"

predictions_dir = "predictions/"
image_subset_dir = "subset_files/"

training_images_dir = "training_validation_Hair_Skin_Masks/training_hair_skin/images/images/"
training_images_flow_dir = "training_validation_Hair_Skin_Masks/training_hair_skin/images/"
testing_images_dir = "testing_images/testing_images/"
validation_images_dir = "training_validation_Hair_Skin_Masks/validation_hair_skin/images/"

training_masks_dir = "training_validation_Hair_Skin_Masks/training_hair_skin/masks/masks/"
training_masks_flow_dir = "training_validation_Hair_Skin_Masks/training_hair_skin/masks/"
validation_masks_dir = "training_validation_Hair_Skin_Masks/validation_hair_skin/masks/"

# %%
# calculate the weighted categorical crossentropy
# for evaluation with a keras model
#

def weighted_cce(y_true, y_pred, weights=np.array([4,1,1])):
    """
    A weighted version of keras.objectives.categorical_crossentropy
    
    Variables:
        weights: numpy array of shape (C,) where C is the number of classes
    
    Usage:
        weights = np.array([0.5,2,10]) # Class one at 0.5, class 2 twice the normal weights, class 3 10x.
        loss = weighted_categorical_crossentropy(weights)
        model.compile(loss=loss,optimizer='adam')
    """
    
    # scale predictions so that the class probas of each sample sum to 1
    y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
    # clip to prevent NaN's and Inf's
    y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
    # calc
    loss = y_true * K.log(y_pred) * weights
    loss = -K.sum(loss, -1)
    
    weights = K.variable(weights)
    
    return loss

# %%
# calculate the dice coefficient of a 
# predicted and true image tensors
#

def dice_coef(y_true, y_pred, smooth=1):
    
    # calculate the magnitude of the intersection between
    # the predicted and true tensors
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    
    # calculate the magnitude of the union of the 
    # predicted and true tensors
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

# %%
# calculate the dice loss for the 
# true and predicted image tensors
#

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %%
# custom implementation of the FCN8 segmentation 
# architecture
#

def fcn8(n_classes, input_size = (256,256,3)):
    
    # input layer
    inputs = Input(input_size)
    
    # layer 1 (256 x 256)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    # layer 2 (128 x 128)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    # layer 3 (64 x 64)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)  
    predict_64x64 = Conv2D(n_classes, 1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)     
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    # layer 4 (32 x 32)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    predict_32x32 = Conv2D(n_classes, 1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    
    # layer 5 (16 x 16)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = Conv2D(n_classes, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    
    # layer 7 (upsampling to 32 x 32)
    up7 = Conv2D(n_classes, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    
    # add layer 4 prediction to layer 7
    merge7 = concatenate([predict_32x32,up7], axis = 3)
    
    # layer 8 (upsampling to 64 x 64)
    up8 = Conv2D(n_classes, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(merge7))
    
    # add layer 3 prediction to layer 8
    merge8 = concatenate([predict_64x64, up8], axis = 3)
    
    # layer 9 (upsampling to 256 x 256)
    up9 = Conv2D(n_classes, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(merge8))
    up9 = Conv2D(n_classes, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(up9))
    
    # output layer
    outputs = Conv2D(n_classes, 1, activation = 'softmax')(up9)

    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
# custom implementation of the U-Net segmentation
# architecture
#

def unet(n_classes, input_size = (256,256,3)):
    
    # input layer
    inputs = Input(input_size)
    
    # layer 1
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    # layer 2
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    # layer 3
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    # layer 4 
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    # layer 5
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)

    # layer 6 (upsampling)
    up6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    
    # take information from layer 4
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    
    # layer 7 (upsampling)
    up7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    
    # take information from layer 3
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    # layer 8 (upsampling)
    up8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    
    # take information from layer 2
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    # layer 9 (upsampling)
    up9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    
    # take information from layer 1
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    # output layer
    outputs = Conv2D(n_classes, 1, activation='softmax')(conv9)

    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
# delete all imagese in the predictions 
# directory
# 
# @predictions_dir: the directory path to be 
#                   cleared
#

def clear_old_predictions(predictions_dir):
    files = os.listdir(predictions_dir)
    for file in files:
        file_path = os.path.join(predictions_dir, file)
        os.remove(file_path)

# %%
# return images from the directory pointed to from dir_path
# as an Numpy array of shape (# of images, image width, image height, channels)
#
# @image_files: an array of strings containing the filepaths to the images
#               to be read from the directory. Used in conjunction with 
#               the files created by get_appropriate_images.ipynb
# @is_mask: If true, images will be converted to binary images and channels 
#           will be set to 1
# 

def get_np_array_images_from_directory(dir_path, image_files=None):
    
    # container for image arrays
    np_arrays = []
    
    # if image_files wasn't specified read all images from directory
    if image_files is None:
        image_files = os.listdir(dir_path)
        image_files = sorted(image_files, key=lambda s:int(s.split('_')[2].split('.')[0]))
    
    # construct the appropriate absolute paths for each image
    image_paths = [os.path.join(dir_path, filename) for filename in image_files]
    
    # read, resize, and convert each image to a Numpy array
    for path in image_paths:
        
        # open image
        img = Image.open(path)
        
        # resize image
        img = img.resize((256, 256))
        
#         # convert to binary image if is_mask is True
#         if is_mask:
#             img = img.convert("1")
        
        # convert image to Numpy array 
        array = np.array(img)
        
#         # ensure mask images have a single color channel dimension
#         if is_mask:
#             array = array.reshape(256, 256, 1)
        
        # add the image to the image arrays container
        np_arrays.append(array)
        
    return np.array(np_arrays)

# %%
# convert a Numpy array containing the information 
# for a mask image to a pillow image
# 
# @np_array: the array containing the binary mask
#            information
#
# @return: a Pillow Image
#

def get_mask_from_binary_array(np_array):
    
    # extract dimensions of image
    height = np_array.shape[0]
    width = np_array.shape[1]
    
    # cut off the channels dimension
    # which should be 1
    np_array = np_array.reshape(height, width)
    
    # convert to 255 black and white representation
    np_array *= 255
    
    return Image.fromarray(np_array)

# %%
# set gpu configuration for this system
#

config = tf.compat.v1.ConfigProto( device_count={'GPU': 1, 'CPU':8})
sess = tf.compat.v1.Session(config=config)
keras.backend.set_session(sess)

# %%
# read in the validation and testing images and masks
#

training_image_arrays = get_np_array_images_from_directory(training_images_dir)
training_mask_arrays = get_np_array_images_from_directory(training_masks_dir)
training_image_arrays = training_image_arrays.astype("float32") / 255.0
training_mask_arrays = training_mask_arrays / 255
training_mask_arrays = training_mask_arrays.astype("int")

validation_image_arrays = get_np_array_images_from_directory(validation_images_dir)
validation_mask_arrays = get_np_array_images_from_directory(validation_masks_dir)
validation_image_arrays = validation_image_arrays.astype("float32") / 255.0
validation_mask_arrays = validation_mask_arrays / 255
validation_mask_arrays = validation_mask_arrays.astype("int")

testing_image_arrays = get_np_array_images_from_directory(testing_images_dir)
testing_image_arrays = testing_image_arrays.astype("float32") / 255.0

# %%
# map of the custom metrics
# 
# required information for models
#

dependencies = {
    "dice_coef": dice_coef,
    "dice_loss": dice_loss,
    "weighted_cce": weighted_cce
}

# %%
# initialize the model
#

# model = fcn8(3)
model = unet(3)

# optimizer = Adam(lr=1e-4) # unet with categorical crossentropy
optimizer = Adam(lr=1e-4) # unet with weighted categorical crossentropy [2.0,1,1]
# optimizer = Adam(lr=5e-5) # unet with dice loss
# optimizer = Adam(lr=1e-3) # fcn8 with categorical crossentropy
# optimizer = Adam(lr=1e-4) # fcn8 with dice loss
# optimizer = Adam(lr=1E-4) # fcn8 with weighted categorical crossentropy [1.5,1,1]
model.compile(optimizer=optimizer, loss=weighted_cce, metrics = [dice_coef])

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Sam\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  4719104     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_7[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  1179904     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 295040      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 73792       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 3)  195         conv2d_21[0][0]
# ==================================================================================================
# Total params: 34,513,475
# Trainable params: 34,513,475
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# the augmentation generators for training
#

datagen_args = dict(
    rotation_range=45,
    rescale=1.0/255.0,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2
)

# augmentation for images and masks must be
# identical
#

train_image_datagen = ImageDataGenerator(**datagen_args, dtype="float32")
train_mask_datagen = ImageDataGenerator(**datagen_args, dtype="int")

seed = 1337
train_image_datagen.fit(training_image_arrays, augment=True, seed=seed)
train_mask_datagen.fit(training_mask_arrays, augment=True, seed=seed)

# %%
# create one generator for the training images
# and another for the training masks
#

generator_args = dict(
    class_mode=None,
    target_size=resize_shape,
    batch_size=batch_size,
    seed=seed
)

train_image_generator = train_image_datagen.flow_from_directory(
    training_images_flow_dir,
    **generator_args
)
train_mask_generator = train_mask_datagen.flow_from_directory(
    training_masks_flow_dir,
    **generator_args
)

train_generator = (pair for pair in zip(train_image_generator, train_mask_generator))
# Out:
# Found 1500 images belonging to 1 classes.
# Found 1500 images belonging to 1 classes.

# %%
# train the model on unaugmented data first and then
# on augmented data
# 

# create the checkpoints for the model
#
checkpoint = ModelCheckpoint(
    weights_file, 
    monitor='val_loss', 
    mode='min', 
    verbose=1, 
    save_best_only=True
)
earlystop = EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=10,
    restore_best_weights=True
)

callbacks = [checkpoint, earlystop]

# train on unaltered images
#
model.fit(
    x=training_image_arrays, y=training_mask_arrays,
    validation_data=(validation_image_arrays, validation_mask_arrays),
    epochs=standard_epochs,
    batch_size=batch_size,
    callbacks=callbacks
)

# train on augmented data
#
model.fit_generator(
    train_generator, 
    epochs=augmented_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=(validation_image_arrays, validation_mask_arrays),
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From C:\Users\Sam\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 1500 samples, validate on 500 samples
# Epoch 1/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.8030 - dice_coef: 0.6702
# Epoch 00001: val_loss improved from inf to 0.59233, saving model to highest.hdf5
# 1500/1500 [==============================] - 147s 98ms/sample - loss: 0.8014 - dice_coef: 0.6708 - val_loss: 0.5923 - val_dice_coef: 0.8045
# Epoch 2/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.5602 - dice_coef: 0.7841
# Epoch 00002: val_loss improved from 0.59233 to 0.54224, saving model to highest.hdf5
# 1500/1500 [==============================] - 142s 94ms/sample - loss: 0.5606 - dice_coef: 0.7837 - val_loss: 0.5422 - val_dice_coef: 0.7702
# Epoch 3/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.5023 - dice_coef: 0.8081
# Epoch 00003: val_loss improved from 0.54224 to 0.50978, saving model to highest.hdf5
# 1500/1500 [==============================] - 142s 94ms/sample - loss: 0.5008 - dice_coef: 0.8084 - val_loss: 0.5098 - val_dice_coef: 0.8394
# Epoch 4/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.4204 - dice_coef: 0.8398
# Epoch 00004: val_loss improved from 0.50978 to 0.37891, saving model to highest.hdf5
# 1500/1500 [==============================] - 142s 95ms/sample - loss: 0.4198 - dice_coef: 0.8400 - val_loss: 0.3789 - val_dice_coef: 0.8616
# Epoch 5/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.3808 - dice_coef: 0.8560
# Epoch 00005: val_loss improved from 0.37891 to 0.33762, saving model to highest.hdf5
# 1500/1500 [==============================] - 142s 95ms/sample - loss: 0.3824 - dice_coef: 0.8558 - val_loss: 0.3376 - val_dice_coef: 0.8596
# Epoch 6/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.3292 - dice_coef: 0.8761
# Epoch 00006: val_loss improved from 0.33762 to 0.30859, saving model to highest.hdf5
# 1500/1500 [==============================] - 142s 95ms/sample - loss: 0.3293 - dice_coef: 0.8760 - val_loss: 0.3086 - val_dice_coef: 0.8785
# Epoch 7/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.2900 - dice_coef: 0.8912
# Epoch 00007: val_loss improved from 0.30859 to 0.29498, saving model to highest.hdf5
# 1500/1500 [==============================] - 142s 95ms/sample - loss: 0.2897 - dice_coef: 0.8912 - val_loss: 0.2950 - val_dice_coef: 0.8794
# Epoch 8/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.2734 - dice_coef: 0.8966
# Epoch 00008: val_loss did not improve from 0.29498
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.2733 - dice_coef: 0.8966 - val_loss: 0.3025 - val_dice_coef: 0.9136
# Epoch 9/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.2311 - dice_coef: 0.9128
# Epoch 00009: val_loss improved from 0.29498 to 0.24816, saving model to highest.hdf5
# 1500/1500 [==============================] - 142s 95ms/sample - loss: 0.2323 - dice_coef: 0.9125 - val_loss: 0.2482 - val_dice_coef: 0.9084
# Epoch 10/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.2082 - dice_coef: 0.9207
# Epoch 00010: val_loss did not improve from 0.24816
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.2085 - dice_coef: 0.9206 - val_loss: 0.2520 - val_dice_coef: 0.9155
# Epoch 11/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.2031 - dice_coef: 0.9233
# Epoch 00011: val_loss did not improve from 0.24816
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.2032 - dice_coef: 0.9232 - val_loss: 0.2759 - val_dice_coef: 0.9048
# Epoch 12/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.2016 - dice_coef: 0.9235
# Epoch 00012: val_loss improved from 0.24816 to 0.24064, saving model to highest.hdf5
# 1500/1500 [==============================] - 142s 94ms/sample - loss: 0.2017 - dice_coef: 0.9234 - val_loss: 0.2406 - val_dice_coef: 0.9145
# Epoch 13/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.1617 - dice_coef: 0.9385
# Epoch 00013: val_loss improved from 0.24064 to 0.23376, saving model to highest.hdf5
# 1500/1500 [==============================] - 142s 95ms/sample - loss: 0.1619 - dice_coef: 0.9384 - val_loss: 0.2338 - val_dice_coef: 0.9264
# Epoch 14/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.1528 - dice_coef: 0.9414
# Epoch 00014: val_loss improved from 0.23376 to 0.22764, saving model to highest.hdf5
# 1500/1500 [==============================] - 142s 94ms/sample - loss: 0.1527 - dice_coef: 0.9415 - val_loss: 0.2276 - val_dice_coef: 0.9334
# Epoch 15/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.1382 - dice_coef: 0.9469
# Epoch 00015: val_loss did not improve from 0.22764
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.1383 - dice_coef: 0.9469 - val_loss: 0.2766 - val_dice_coef: 0.9310
# Epoch 16/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.1362 - dice_coef: 0.9477
# Epoch 00016: val_loss did not improve from 0.22764
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.1362 - dice_coef: 0.9477 - val_loss: 0.2592 - val_dice_coef: 0.9401
# Epoch 17/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.1103 - dice_coef: 0.9570
# Epoch 00017: val_loss did not improve from 0.22764
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.1105 - dice_coef: 0.9569 - val_loss: 0.2422 - val_dice_coef: 0.9356
# Epoch 18/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.1001 - dice_coef: 0.9608
# Epoch 00018: val_loss did not improve from 0.22764
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.1001 - dice_coef: 0.9608 - val_loss: 0.3289 - val_dice_coef: 0.9428
# Epoch 19/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.0954 - dice_coef: 0.9625
# Epoch 00019: val_loss did not improve from 0.22764
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.0954 - dice_coef: 0.9625 - val_loss: 0.3244 - val_dice_coef: 0.9460
# Epoch 20/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.0942 - dice_coef: 0.9632
# Epoch 00020: val_loss did not improve from 0.22764
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.0944 - dice_coef: 0.9632 - val_loss: 0.3199 - val_dice_coef: 0.9373
# Epoch 21/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.1372 - dice_coef: 0.9479
# Epoch 00021: val_loss did not improve from 0.22764
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.1369 - dice_coef: 0.9480 - val_loss: 0.2880 - val_dice_coef: 0.9437
# Epoch 22/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.0886 - dice_coef: 0.9654
# Epoch 00022: val_loss did not improve from 0.22764
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.0888 - dice_coef: 0.9654 - val_loss: 0.2743 - val_dice_coef: 0.9427
# Epoch 23/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.0759 - dice_coef: 0.9699
# Epoch 00023: val_loss did not improve from 0.22764
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.0759 - dice_coef: 0.9700 - val_loss: 0.3094 - val_dice_coef: 0.9478
# Epoch 24/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.0684 - dice_coef: 0.9728
# Epoch 00024: val_loss did not improve from 0.22764
# 1500/1500 [==============================] - 140s 93ms/sample - loss: 0.0684 - dice_coef: 0.9728 - val_loss: 0.3239 - val_dice_coef: 0.9497
# Epoch 1/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.3912 - dice_coef: 0.8516Epoch 1/100
# 500/151 [===================================================================================================] - 14s 29ms/sample - loss: 0.2660 - dice_coef: 0.8981
#
# Epoch 00001: val_loss did not improve from 0.22764
# 151/151 [==============================] - 139s 921ms/step - loss: 0.3909 - dice_coef: 0.8518 - val_loss: 0.2567 - val_dice_coef: 0.8981
# Epoch 2/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.3231 - dice_coef: 0.8780Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2795 - dice_coef: 0.8858
#
# Epoch 00002: val_loss did not improve from 0.22764
# 151/151 [==============================] - 139s 919ms/step - loss: 0.3230 - dice_coef: 0.8779 - val_loss: 0.2774 - val_dice_coef: 0.8858
# Epoch 3/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.2908 - dice_coef: 0.8911Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2506 - dice_coef: 0.8865
#
# Epoch 00003: val_loss did not improve from 0.22764
# 151/151 [==============================] - 139s 919ms/step - loss: 0.2907 - dice_coef: 0.8912 - val_loss: 0.2524 - val_dice_coef: 0.8865
# Epoch 4/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.2669 - dice_coef: 0.8986Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2614 - dice_coef: 0.9074
#
# Epoch 00004: val_loss did not improve from 0.22764
# 151/151 [==============================] - 139s 919ms/step - loss: 0.2675 - dice_coef: 0.8986 - val_loss: 0.2390 - val_dice_coef: 0.9074
# Epoch 5/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.2676 - dice_coef: 0.8979Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2571 - dice_coef: 0.9256
#
# Epoch 00005: val_loss did not improve from 0.22764
# 151/151 [==============================] - 139s 919ms/step - loss: 0.2675 - dice_coef: 0.8980 - val_loss: 0.2403 - val_dice_coef: 0.9256
# Epoch 6/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.2410 - dice_coef: 0.9087Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2303 - dice_coef: 0.9139
#
# Epoch 00006: val_loss improved from 0.22764 to 0.22267, saving model to highest.hdf5
# 151/151 [==============================] - 141s 933ms/step - loss: 0.2413 - dice_coef: 0.9086 - val_loss: 0.2227 - val_dice_coef: 0.9139
# Epoch 7/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.2307 - dice_coef: 0.9120Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2140 - dice_coef: 0.9276
#
# Epoch 00007: val_loss improved from 0.22267 to 0.20525, saving model to highest.hdf5
# 151/151 [==============================] - 141s 933ms/step - loss: 0.2314 - dice_coef: 0.9120 - val_loss: 0.2052 - val_dice_coef: 0.9276
# Epoch 8/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.2264 - dice_coef: 0.9140Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2067 - dice_coef: 0.9293
#
# Epoch 00008: val_loss improved from 0.20525 to 0.20329, saving model to highest.hdf5
# 151/151 [==============================] - 141s 933ms/step - loss: 0.2264 - dice_coef: 0.9140 - val_loss: 0.2033 - val_dice_coef: 0.9293
# Epoch 9/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.2232 - dice_coef: 0.9155Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2458 - dice_coef: 0.9242
#
# Epoch 00009: val_loss did not improve from 0.20329
# 151/151 [==============================] - 139s 918ms/step - loss: 0.2231 - dice_coef: 0.9155 - val_loss: 0.2272 - val_dice_coef: 0.9242
# Epoch 10/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.2015 - dice_coef: 0.9227Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2040 - dice_coef: 0.9322
#
# Epoch 00010: val_loss improved from 0.20329 to 0.19724, saving model to highest.hdf5
# 151/151 [==============================] - 141s 932ms/step - loss: 0.2021 - dice_coef: 0.9227 - val_loss: 0.1972 - val_dice_coef: 0.9322
# Epoch 11/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1996 - dice_coef: 0.9231Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.3459 - dice_coef: 0.9265
#
# Epoch 00011: val_loss did not improve from 0.19724
# 151/151 [==============================] - 139s 919ms/step - loss: 0.1990 - dice_coef: 0.9233 - val_loss: 0.3332 - val_dice_coef: 0.9265
# Epoch 12/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.2051 - dice_coef: 0.9223Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2108 - dice_coef: 0.9357
#
# Epoch 00012: val_loss did not improve from 0.19724
# 151/151 [==============================] - 139s 918ms/step - loss: 0.2055 - dice_coef: 0.9224 - val_loss: 0.2209 - val_dice_coef: 0.9357
# Epoch 13/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1936 - dice_coef: 0.9261Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2096 - dice_coef: 0.9292
#
# Epoch 00013: val_loss did not improve from 0.19724
# 151/151 [==============================] - 139s 919ms/step - loss: 0.1941 - dice_coef: 0.9260 - val_loss: 0.2036 - val_dice_coef: 0.9292
# Epoch 14/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.2013 - dice_coef: 0.9230Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2604 - dice_coef: 0.9311
#
# Epoch 00014: val_loss did not improve from 0.19724
# 151/151 [==============================] - 139s 918ms/step - loss: 0.2012 - dice_coef: 0.9230 - val_loss: 0.2354 - val_dice_coef: 0.9311
# Epoch 15/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1904 - dice_coef: 0.9266Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1896 - dice_coef: 0.9306
#
# Epoch 00015: val_loss improved from 0.19724 to 0.19686, saving model to highest.hdf5
# 151/151 [==============================] - 141s 933ms/step - loss: 0.1906 - dice_coef: 0.9266 - val_loss: 0.1969 - val_dice_coef: 0.9306
# Epoch 16/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1815 - dice_coef: 0.9309Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2033 - dice_coef: 0.9303
#
# Epoch 00016: val_loss improved from 0.19686 to 0.19460, saving model to highest.hdf5
# 151/151 [==============================] - 140s 930ms/step - loss: 0.1813 - dice_coef: 0.9309 - val_loss: 0.1946 - val_dice_coef: 0.9303
# Epoch 17/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1745 - dice_coef: 0.9331Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2153 - dice_coef: 0.9342
#
# Epoch 00017: val_loss did not improve from 0.19460
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1743 - dice_coef: 0.9332 - val_loss: 0.2072 - val_dice_coef: 0.9342
# Epoch 18/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1773 - dice_coef: 0.9320Epoch 1/100
# 500/151 [===================================================================================================] - 14s 29ms/sample - loss: 0.1903 - dice_coef: 0.9396
#
# Epoch 00018: val_loss did not improve from 0.19460
# 151/151 [==============================] - 139s 919ms/step - loss: 0.1779 - dice_coef: 0.9320 - val_loss: 0.1979 - val_dice_coef: 0.9396
# Epoch 19/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1760 - dice_coef: 0.9318Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2064 - dice_coef: 0.9395
#
# Epoch 00019: val_loss did not improve from 0.19460
# 151/151 [==============================] - 139s 919ms/step - loss: 0.1762 - dice_coef: 0.9318 - val_loss: 0.2087 - val_dice_coef: 0.9395
# Epoch 20/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1751 - dice_coef: 0.9326Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1762 - dice_coef: 0.9296
#
# Epoch 00020: val_loss improved from 0.19460 to 0.19071, saving model to highest.hdf5
# 151/151 [==============================] - 141s 932ms/step - loss: 0.1749 - dice_coef: 0.9327 - val_loss: 0.1907 - val_dice_coef: 0.9296
# Epoch 21/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1626 - dice_coef: 0.9371Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1979 - dice_coef: 0.9351
#
# Epoch 00021: val_loss did not improve from 0.19071
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1622 - dice_coef: 0.9371 - val_loss: 0.2012 - val_dice_coef: 0.9351
# Epoch 22/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1595 - dice_coef: 0.9384Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1973 - dice_coef: 0.9346
#
# Epoch 00022: val_loss did not improve from 0.19071
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1595 - dice_coef: 0.9383 - val_loss: 0.1992 - val_dice_coef: 0.9346
# Epoch 23/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1746 - dice_coef: 0.9339Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1969 - dice_coef: 0.9282
#
# Epoch 00023: val_loss did not improve from 0.19071
# 151/151 [==============================] - 139s 919ms/step - loss: 0.1744 - dice_coef: 0.9339 - val_loss: 0.1924 - val_dice_coef: 0.9282
# Epoch 24/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1556 - dice_coef: 0.9406Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1964 - dice_coef: 0.9407
#
# Epoch 00024: val_loss did not improve from 0.19071
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1555 - dice_coef: 0.9406 - val_loss: 0.1966 - val_dice_coef: 0.9407
# Epoch 25/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1504 - dice_coef: 0.9416Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1949 - dice_coef: 0.9320
#
# Epoch 00025: val_loss did not improve from 0.19071
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1506 - dice_coef: 0.9415 - val_loss: 0.1910 - val_dice_coef: 0.9320
# Epoch 26/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1647 - dice_coef: 0.9367Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1832 - dice_coef: 0.9322
#
# Epoch 00026: val_loss improved from 0.19071 to 0.18601, saving model to highest.hdf5
# 151/151 [==============================] - 141s 933ms/step - loss: 0.1644 - dice_coef: 0.9368 - val_loss: 0.1860 - val_dice_coef: 0.9322
# Epoch 27/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1527 - dice_coef: 0.9410Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2294 - dice_coef: 0.9432
#
# Epoch 00027: val_loss did not improve from 0.18601
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1524 - dice_coef: 0.9411 - val_loss: 0.2131 - val_dice_coef: 0.9432
# Epoch 28/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1465 - dice_coef: 0.9430Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2140 - dice_coef: 0.9404
#
# Epoch 00028: val_loss did not improve from 0.18601
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1463 - dice_coef: 0.9430 - val_loss: 0.2026 - val_dice_coef: 0.9404
# Epoch 29/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1427 - dice_coef: 0.9446Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1907 - dice_coef: 0.9471
#
# Epoch 00029: val_loss did not improve from 0.18601
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1427 - dice_coef: 0.9447 - val_loss: 0.2017 - val_dice_coef: 0.9471
# Epoch 30/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1433 - dice_coef: 0.9447Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2229 - dice_coef: 0.9221
#
# Epoch 00030: val_loss did not improve from 0.18601
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1436 - dice_coef: 0.9446 - val_loss: 0.2143 - val_dice_coef: 0.9221
# Epoch 31/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1571 - dice_coef: 0.9395Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1969 - dice_coef: 0.9409
#
# Epoch 00031: val_loss did not improve from 0.18601
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1570 - dice_coef: 0.9395 - val_loss: 0.1935 - val_dice_coef: 0.9409
# Epoch 32/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1422 - dice_coef: 0.9447Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.1994 - dice_coef: 0.9387
#
# Epoch 00032: val_loss did not improve from 0.18601
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1424 - dice_coef: 0.9446 - val_loss: 0.1965 - val_dice_coef: 0.9387
# Epoch 33/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1438 - dice_coef: 0.9439Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2164 - dice_coef: 0.9452
#
# Epoch 00033: val_loss did not improve from 0.18601
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1435 - dice_coef: 0.9440 - val_loss: 0.2167 - val_dice_coef: 0.9452
# Epoch 34/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1478 - dice_coef: 0.9431Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2165 - dice_coef: 0.9440
#
# Epoch 00034: val_loss did not improve from 0.18601
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1477 - dice_coef: 0.9432 - val_loss: 0.1950 - val_dice_coef: 0.9440
# Epoch 35/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1307 - dice_coef: 0.9489Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2331 - dice_coef: 0.9495
#
# Epoch 00035: val_loss did not improve from 0.18601
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1304 - dice_coef: 0.9490 - val_loss: 0.2267 - val_dice_coef: 0.9495
# Epoch 36/100
# 150/151 [============================>.] - ETA: 0s - loss: 0.1305 - dice_coef: 0.9491Epoch 1/100
# 500/151 [===================================================================================================] - 14s 28ms/sample - loss: 0.2146 - dice_coef: 0.9436
#
# Epoch 00036: val_loss did not improve from 0.18601
# 151/151 [==============================] - 139s 918ms/step - loss: 0.1306 - dice_coef: 0.9490 - val_loss: 0.2313 - val_dice_coef: 0.9436

# %%
# load the model with the lowest validation loss
#

loaded_model = load_model(weights_file, custom_objects=dependencies)
# Out:
# WARNING:tensorflow:From C:\Users\Sam\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Sam\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Sam\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# make predictions
#
predictions = loaded_model.predict(testing_image_arrays, batch_size=1)

# only classify the areas containing hair
# all other areas should be black
#
classes = (predictions.argmax(axis=-1) == 0).astype("int")

# %%
# check for correct shapes
#
print(classes.shape)
print(predictions.shape)
# Out:
# (927, 256, 256)
# (927, 256, 256, 3)

# %%
# visually inspect the results of the 
# prediction for variation 
# 
# constant values indicate a problem with
# the training
#
for row in predictions[0]:
    print(row)
# Out:
# [[7.5998940e-02 5.4616630e-03 9.1853940e-01]
#  [3.5013903e-02 7.0207193e-04 9.6428406e-01]
#  [2.5561079e-02 2.5032891e-04 9.7418857e-01]
#  [1.3265696e-02 7.3217452e-05 9.8666102e-01]
#  [7.8465603e-03 3.7016081e-05 9.9211639e-01]
#  [6.1750086e-03 2.6597007e-05 9.9379843e-01]
#  [5.2906550e-03 2.4808247e-05 9.9468452e-01]
#  [4.8550186e-03 2.3276089e-05 9.9512166e-01]
#  [4.5407414e-03 2.1025960e-05 9.9543828e-01]
#  [4.4150888e-03 1.9880634e-05 9.9556500e-01]
#  [4.2179874e-03 1.8746163e-05 9.9576318e-01]
#  [4.1957451e-03 1.8699211e-05 9.9578553e-01]
#  [4.1542696e-03 1.9248260e-05 9.9582642e-01]
#  [4.0849638e-03 1.9627067e-05 9.9589539e-01]
#  [3.9911144e-03 2.0792457e-05 9.9598807e-01]
#  [3.9649899e-03 2.1924659e-05 9.9601305e-01]
#  [3.9949417e-03 2.2799986e-05 9.9598229e-01]
#  [9.22413588e-01 1.07351653e-02 6.68511912e-02]
#  [9.17798460e-01 1.14885140e-02 7.07130507e-02]
#  [9.08937991e-01 1.33635234e-02 7.76984617e-02]
#  [8.98919880e-01 1.58106033e-02 8.52694884e-02]
#  [8.87750626e-01 1.83523726e-02 9.38970000e-02]
#  [8.75973344e-01 1.95292011e-02 1.04497492e-01]
#  [8.38282943e-01 2.11918280e-02 1.40525252e-01]
#  [7.63121307e-01 2.10136026e-02 2.15865105e-01]
#  [5.44601440e-01 1.72944535e-02 4.38104123e-01]
#  [2.70689338e-01 8.74720514e-03 7.20563471e-01]
#  [1.79321498e-01 3.90158314e-03 8.16776931e-01]
#  [1.55047700e-01 2.38614366e-03 8.42566133e-01]
#  [1.57253399e-01 1.74889492e-03 8.40997696e-01]
#  [1.42336905e-01 1.56880438e-03 8.56094301e-01]
#  [1.34681910e-01 1.46703550e-03 8.63851070e-01]
#  [1.28304765e-01 1.32888323e-03 8.70366335e-01]
#  [1.23205349e-01 1.07921555e-03 8.75715435e-01]
#  [1.15637392e-01 8.65513342e-04 8.83497119e-01]
#  [1.08210072e-01 6.91379071e-04 8.91098499e-01]
#  [1.00050770e-01 5.97000180e-04 8.99352193e-01]
#  [9.05412957e-02 5.05138421e-04 9.08953547e-01]
#  [8.15714300e-02 3.94518167e-04 9.18034077e-01]
#  [7.31251761e-02 3.04856832e-04 9.26569879e-01]
#  [6.47803992e-02 2.21934970e-04 9.34997618e-01]
#  [5.67033850e-02 1.65384859e-04 9.43131208e-01]
#  [4.91187014e-02 1.24458165e-04 9.50756788e-01]
#  [4.30501699e-02 9.79924007e-05 9.56851840e-01]
#  [3.76073495e-02 7.91769125e-05 9.62313473e-01]
#  [3.50823142e-02 6.53516981e-05 9.64852393e-01]
#  [3.35869566e-02 5.34059327e-05 9.66359675e-01]
#  [3.26043554e-02 4.37251329e-05 9.67351913e-01]
#  [3.11018527e-02 3.87623659e-05 9.68859315e-01]
#  [3.10604889e-02 3.68926085e-05 9.68902647e-01]
#  [2.88970210e-02 3.56450910e-05 9.71067369e-01]
#  [2.64856461e-02 3.67585781e-05 9.73477542e-01]
#  [2.46400200e-02 4.19929711e-05 9.75318015e-01]
#  [2.30006408e-02 5.99328923e-05 9.76939499e-01]
#  [2.39169337e-02 6.64476756e-05 9.76016581e-01]
#  [2.19716765e-02 5.92516808e-05 9.77969050e-01]
#  [1.52176674e-02 7.39586030e-05 9.84708428e-01]
#  [1.24873230e-02 2.83939386e-04 9.87228751e-01]]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# open a single image to visually inspect
#

img_arr = (classes[3] * 255).reshape(256, 256)
print(img_arr.shape)
img = Image.fromarray(img_arr)
img.show()
# Out:
# (256, 256)

# %%
# clear the predictions directory and save
# the new predictions
#
clear_old_predictions(predictions_dir)

save_tag = "test_mask"

i = 1
for c in classes:
    img = get_mask_from_binary_array(c)
    img = img.resize((250, 250))
    img.save(os.path.join(predictions_dir, "{}_{}.png".format(save_tag, str(i))), format="PNG")
    i += 1

# %%
# sound alarm when model finishes training
#

duration = 5000  # milliseconds
freq = 440  # Hz
winsound.Beep(freq, duration)
